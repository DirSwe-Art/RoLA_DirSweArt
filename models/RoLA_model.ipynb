# %%
from LSTM_model import LSTM
import numpy as np
import random
import torch
import time
from datetime import timedelta
from collections import deque
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import ASYNCHRONOUS

# %%
# Setting random seed for reproducibility
torch.manual_seed(140)
np.random.seed(140)
random.seed(140)

# %%
# Functions for RePAD2
def calculate_aare(actual, predicted):
    """
    Calculate the Absolute Relative Error (ARE) between an actual and predicted value.
    
    Parameters:
    actual (deque): The actual value.
    predicted (deque): The predicted value.
    
    Returns:
    float: The Absolute Relative Error.
    """
    # Adding a small value epsilon to avoid division by zero
    #epsilon = 1e-10
    aare_values = []
    
    for act, pred in zip(actual, predicted):
        AARE = abs(act - pred) / max(abs(act), 1)
        aare_values.append(AARE)

    mean_aare = np.mean(aare_values)

    return mean_aare


def calculate_threshold(aare_values):
    """
    Calculate the threshold value (Thd) based on a deque of AARE values.
    Thd is defined as the mean of the AARE values plus three times their standard deviation.

    Parameters:
    - aare_values (array-like): An array of AARE values.

    Returns:
    - float: The calculated threshold value (Thd).
    """
    # Calculate the mean and standard deviation of the AARE values
    mean_aare = np.mean(aare_values)
    std_aare = np.std(aare_values)
    
    # Calculate Thd
    thd = mean_aare + 3 * std_aare
    
    return thd

# Function for creating and training model
def train_model(train_events):
    tensor_y = torch.tensor(train_events, dtype=torch.float32).view(-1, 1, 1)
    tensor_x = torch.tensor([1, 2, 3], dtype=torch.float32).view(-1, 1, 1)
    # Create an instance of the LSTM model
    model = LSTM(tensor_x, tensor_y, input_size=1, hidden_size=10, num_layers=1, output_size=1, num_epochs=50, learning_rate=0.005)
    
    model.train_model() # Train the model

    return model

# Function for reporting anomalies to InfluxDB
def report_anomaly(T, timestamp, actual_value, predicted_value, write_api):
    """
    Sends an anomalous event back to InfluxDB, storing it in the "anomaly" measurement
    with both the same value and time as the original event.

    Parameters:
    - anomalous_event: The event data that was detected as an anomaly, including its value and timestamp.
    """

    point = Point("base_detection_multivariate_dataset")\
        .tag("host", "detector")\
        .field("T", float(T))\
        .field("actual_value", float(actual_value))\
        .field("predicted_value", float(predicted_value))\
        .time(timestamp, WritePrecision.NS)
    
    #write_api.write(bucket="anomalies", org="ORG", record=point)
    #print(f"Anomalous event sent to InfluxDB: Value={actual_value}, Time={timestamp}")

def write_result(timestamp, T, actual_value, predicted_value, AARE, Thd, write_api):
    """
    Sends an anomalous event back to InfluxDB, storing it in the "anomaly" measurement
    with both the same value and time as the original event.

    Parameters:
    - anomalous_event: The event data that was detected as an anomaly, including its value and timestamp.
    """

    point = Point("base_result_multivariate_dataset")\
        .tag("host", "detector")\
        .field("T", float(T))\
        .field("actual_value", float(actual_value))\
        .field("predicted_value", float(predicted_value))\
        .field("AARE", float(AARE))\
        .field("Thd", float(Thd))\
        .time(timestamp, WritePrecision.NS)
    
    write_api.write(bucket="anomalies", org="ORG", record=point)
    print(f'T: {T}, Real Value: {actual_value}, Prediction Value: {predicted_value}, AARE: {AARE}, Thd: {Thd}')

# %%
### RoLA Algorithm ###

def is_anomaly(T, variable_name, state):
	"""
    This function is an LDA-based anomaly detection function that checks if a given
	data point (variable Vx at time T) is an anomaly. 
	It updates variable LDA's parameters dynamically.
	In the multivariate case, each flux event consists of a time stamp and a combination of values.
	These values are treated as floats or other data types. Thus, get_value() was not used as we did a flux event with an one value. 
	
	Parameters:
	===========
	T:					The given time point of the data point.
	variable_name:		The name of the variable of the data point. 
	state:				A nested dictionary containes dictionaries associated with each variable, which containes
						specific arguments for an LDA to store and update relevant data, such as:
	
	  *	batch_events:	A batch (type deque) of four time points events D_T-3, D_T-2, D_T-1, and D_T. It should be updated in each iteration.
						It is used for predicting D_T+1 using batch_events[1:], and predicting D_T using batch_events[0:-1].	
	  *	next_event:		The event to predict next when T = 0, 1, 2, 3, 4, 5, and 6. It should be updated in each iteration.
	  *	M:				A trained LSTM model. Default value is "None". 
	  *	flag:			A flag that indicates whether an anomaly was ditected (falg=False) in the previous iteration. Default value is "True".
	  *	actual_value:	A deque type window of three elements to store the actual value of events within three iterations to calculate the AARE.
	  *	predicted_value: A deque type window of three elements to store the predicted value of events within three iterations to calculate the AARE.
	  *	sliding_window_AARE: A deque type window to store the AARE resulted in each iteration in order to calculate the threhold later.
	
	Return:				The flag indicating the anomaly, together with updated batch events, next events, actual_value, predicted_value, 
	=======				sliding_window_AARE, and the model that will be used in the next iteration.
    """
	
	# For printing the values
	AARE_T = 0
	Thd = 0
	variable_state   = state[variable_name]
	
	batch_events	= variable_state["batch_events"]
	next_event    	= variable_state["next_event"]
	M                   	= variable_state["M"]
	flag			= variable_state["flag"]
	actual_value	= variable_state["actual_value"]
	predicted_value	= variable_state["predicted_value"]
	sliding_window_AARE = variable_state["sliding_window_AARE"]

	# Initialize the LDA
	if T >= 2 and T < 5:
		# Make predictions of D_T+1 by training M with D_T-2, D_T-1, and D_T, i.e., (batch_events)[1:]. 
		
		# batch_events containes only 3 values when T=2.
		if T==2: 
			M = train_model([event for event in list(batch_events)])
			variable_state["M"] = M
		
		# Ignore D_T-3 from the batch_events
		else:
			M = train_model([event for event in list(batch_events)[1:]])
			variable_state["M"] = M
		
		pred_D_T_plus_1 = M.predict_next()
		
		# Append the event and its prediction to the sliding window.
		actual_value.append(next_event)
		predicted_value.append(pred_D_T_plus_1)
		
		# Write the results to InfluxDB.
		#write_result(batch_events[-1].get_time(), T, batch_events[-1].get_value(), predicted_value[-2], AARE_T, Thd, write_api) 
		
		#return batch_events, next_event, M, actual_value, predicted_value, sliding_window_AARE, flag
		return False

	elif T >= 5 and T < 7:
		# Calculate AARE and append to sliding window.
		AARE_T = calculate_aare(actual_value, predicted_value)
		sliding_window_AARE.append(AARE_T)
		
		# Train M with (D_T-2, D_T-1, and D_T) to predict D_T+1.
		M = train_model([event for event in list(batch_events)[1:]])
		pred_D_T_plus_1 = M.predict_next()
		
		# Append the event and its prediction to the sliding window.
		actual_value.append(next_event)
		predicted_value.append(pred_D_T_plus_1)

		# Update M for the next iteration. This has no effect with T=6, but is needed in the iteration when T>7
		variable_state["M"] = M
		
		# Write the results to InfluxDB.
		#write_result(batch_events[-1].get_time(), T, batch_events[-1].get_value(), predicted_value[-2], AARE_T, Thd, write_api) 

		#return batch_events, next_event,  M, actual_value, predicted_value, sliding_window_AARE, flag
		return False
		
	# Make predictions of D_T by training M with D_T-3, D_T-2, D_T-1, i.e., (batch_events)[0:-1]
	elif T >= 7 and flag == True:							
		if T != 7:
			# Use M to precdict D_T.
			pred_D_T = M.predict_next()
			
			# Append the event (last event in batch_events) and its prediction to the sliding window.
			actual_value.append(batch_events[-1])
			predicted_value.append(pred_D_T)

		# Calculate AARE and append to sliding window	
		AARE_T = calculate_aare(actual_value, predicted_value)
		sliding_window_AARE.append(AARE_T)
		
		# Calculate Thd
		Thd = calculate_threshold(sliding_window_AARE)
		
		if AARE_T <= Thd: pass 		# D_T is not reported as anomaly
		else:																
			# Train an LSTM model with D_T-3, D_T-2, D_T-1: list(batch_events)[0:-1]		  
			model = train_model([event for event in list(batch_events)[0:-1]]) 
			# Use the model to predict D_T
			pred_D_T = model.predict_next()
			
			# Append the event (last event in batch_events) and its prediction to the sliding window
			actual_value.append(batch_events[-1])
			predicted_value.append(pred_D_T)

			# Re-calculate AARE_T
			AARE_T = calculate_aare(actual_value, predicted_value)
			sliding_window_AARE.append(AARE_T)
			
			# Re-calculate Thd
			Thd = calculate_threshold(sliding_window_AARE)

			if AARE_T <= Thd:
				# D_T is not reported as anomaly
				# Replace M with the new model
				#M = model
				variable_state["M"] = model
				# Update flag to True
				flag = True
			else:
				# D_T reported as anomaly immediately, and update flag to False
				flag = False
				#report_anomaly(T, batch_events[-1].get_time(), actual_value[-1], predicted_value[-1], write_api)
				
		# Write the results to InfluxDB																							### delete later
		#write_result(batch_events[-1].get_time(), T, batch_events[-1].get_value(), predicted_value[-1], AARE_T, Thd, write_api) 	### delete later
		#return batch_events, next_event, M, actual_value, predicted_value, sliding_window_AARE, flag
		return not flag	

	elif T >= 7 and flag == False:
		# Train an LSTM model with D_T-3, D_T-2, D_T-1
		model = train_model([event for event in list(batch_events)[0:-1]])
		# Use the model to predict D_T
		pred_D_T = model.predict_next()
		# Append the event and its prediction to the sliding window
		actual_value.append(batch_events[-1])
		predicted_value.append(pred_D_T) 

		# Calculate AARE_T
		AARE_T = calculate_aare(actual_value, predicted_value)
		sliding_window_AARE.append(AARE_T)
		# Calculate Thd
		Thd = calculate_threshold(sliding_window_AARE)

		if AARE_T <= Thd:
			# D_T is not reported as anomaly
			# Replace M with the new model
			#M = model
			variable_state["M"] = model
			# Update flag to True
			flag = True
		else:
			# D_T reported as anomaly immediately, and update flag to False
			flag = False
			#report_anomaly(T, batch_events[-1].get_time(), actual_value[-1], predicted_value[-1], write_api)
		
		# Write the results to InfluxDB																							### delete later
		#write_result(batch_events[-1].get_time(), T, batch_events[-1].get_value(), predicted_value[-1], AARE_T, Thd, write_api) 	### delete later
		#return batch_events, next_event, M, actual_value, predicted_value, sliding_window_AARE, flag
		return not flag
		
# Setting up the InfluxDB to consume data
influxdb_url = "http://localhost:8086"
token = "random_token"
username = "influx-admin"
password = "ThisIsNotThePasswordYouAreLookingFor"
org = "ORG"
bucket = "system_state"
measurement = "multivariate_dataset" 

# Instantiate the QueryAPI
client = InfluxDBClient(url=influxdb_url, token=token, org=org, username=username, password=password)
write_api = client.write_api(write_options=ASYNCHRONOUS)
query_api = client.query_api()

# Sttings
T = 0											# Time point
A, L_var, L_data       = [], [], []					# Lists for storing polling results
C_agree, C_disagree = 0, 0						# Counters
poll_interval = 1  								# Time parameter: Second(s)
time_increment = 1 								# Time parameter: Second(s)
start_time = "2021-10-28T00:00:00Z" 				# The timestamp of the first event to start with in the given time series dataset


# Initialize a state dictionary for each variable where each LDA stores and updates its arguments, such as 
# the batch events, trained model, the flag, and others.
variables = ["SEB45Salinity", "SEB45Conductivity", "OptodeConcentration", "OptodeSaturation", 
			"C3Temperature", "FlowTemperature", "OptodeTemperature", "C3Turbidity", "FlowFlow"]
state        = { 
			key:{"batch_events": 	deque(maxlen=4), 
				 "next_event": 		deque(maxlen=1), 
				 "actual_value": 	deque([0] * 3, maxlen=3), 
				 "predicted_value": 	deque([0] * 3, maxlen=3), 
				 "sliding_window_AARE": deque(maxlen=8064), 
				 "M": 				None, 
				 "flag": 			True }
			for key in variables 
			}

   
	
while True:
	# Construct the Flux query for the available time points with multiple variables
	query = f'''
			from(bucket: "{bucket}")
				|> range(start: time(v: "{start_time}"))
				|> filter(fn: (r) => r["_measurement"] == "{measurement}")
				|> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
			'''

	# Query the data
	events = list(query_api.query_stream(org=org, query=query))

	
	if len(events) > 1: 						# Need at least 3 events to predict next.
		timestamp = 0						# The timestamp of the last processed event.
		for i in range(len(events)):			# Iterate over each data point.
			event = events[i]				# The data point expressed by N-dimensional vector at time point T received by Flux query of readings sent by Kafka1.
			timestamp = event["_time"]  		# Extract timestamp.
				
			# Iterate over each variable. Distribute variables to LDAs
			for variable, value in event.values.items():
				if variable in ["result", "table","_start","_stop","_time","_measurement","host"]: continue

				# Send variable's value (at time T) to the variable LDA's "bach_events" argument stored in the state dictionary.
				state[variable]["batch_events"].append(value)
				
				# Send the variable's next value (at time T+1) to the variable LDA's "next_event" argument stored in the state dictionary. 
				# This is used for an LDA to predict the next event when  0 <= T < 7. The 7th event is the last one predicted.
				if i < 7: 
					state[variable]["next_event"] = events[i+1][variable]	 	

				# Run anomaly detection of the specific variable at time T with updated state.
				anomaly = is_anomaly(T, variable, state)
				
				# Print result
				if anomaly:
					print(f"T: {T}, Timestamp: {timestamp}, Variable: {variable}, Value: {value}, Anomaly: {anomaly}")
				
			
			


			
			#batch_events, next_event, M, actual_value, predicted_value, sliding_window_AARE, flag = is_anomaly(T, batch_events, next_event, M, flag, actual_value, predicted_value, sliding_window_AARE)

			#if flag==False:
			#	print(T, batch_events[-1].get_time())

			# Increment T
			T += 1

		print('timestamp', timestamp)
		# Update start time for the next iteration
		last_event_time = timestamp
		#last_event_time = batch_events[-1].get_time()
		# Increment by 1 second to avoid duplicate events
		start_time = (last_event_time + timedelta(seconds=time_increment)).isoformat()
				

	else:
		print("No events found in range.")

	time.sleep(poll_interval)
# Out:
# T: 21, Timestamp: 2021-10-28 00:21:00+00:00, Variable: C3Temperature, Value: 30.20999908, Anomaly: True
# T: 24, Timestamp: 2021-10-28 00:24:00+00:00, Variable: OptodeSaturation, Value: 94.93000031, Anomaly: True
# T: 66, Timestamp: 2021-10-28 01:06:00+00:00, Variable: OptodeConcentration, Value: 222.5399933, Anomaly: True
# T: 78, Timestamp: 2021-10-28 01:18:00+00:00, Variable: C3Turbidity, Value: 4.21, Anomaly: True
# T: 79, Timestamp: 2021-10-28 01:19:00+00:00, Variable: C3Turbidity, Value: 1.16, Anomaly: True
# T: 80, Timestamp: 2021-10-28 01:20:00+00:00, Variable: C3Turbidity, Value: 1.08, Anomaly: True
# T: 111, Timestamp: 2021-10-28 01:51:00+00:00, Variable: FlowTemperature, Value: 31.70000076, Anomaly: True
# T: 115, Timestamp: 2021-10-28 01:55:00+00:00, Variable: FlowTemperature, Value: 31.70000076, Anomaly: True
# T: 194, Timestamp: 2021-10-28 03:14:00+00:00, Variable: OptodeConcentration, Value: 222.4199982, Anomaly: True
# T: 205, Timestamp: 2021-10-28 03:25:00+00:00, Variable: FlowFlow, Value: 12.5, Anomaly: True
# T: 221, Timestamp: 2021-10-28 03:41:00+00:00, Variable: FlowTemperature, Value: 31.89999962, Anomaly: True
# T: 388, Timestamp: 2021-10-28 06:28:00+00:00, Variable: FlowTemperature, Value: 31.70000076, Anomaly: True
# T: 388, Timestamp: 2021-10-28 06:28:00+00:00, Variable: SEB45Salinity, Value: 34.508, Anomaly: True
# T: 389, Timestamp: 2021-10-28 06:29:00+00:00, Variable: FlowTemperature, Value: 31.70000076, Anomaly: True
# T: 389, Timestamp: 2021-10-28 06:29:00+00:00, Variable: SEB45Salinity, Value: 34.527, Anomaly: True
# T: 390, Timestamp: 2021-10-28 06:30:00+00:00, Variable: SEB45Salinity, Value: 34.531, Anomaly: True
# T: 405, Timestamp: 2021-10-28 06:45:00+00:00, Variable: OptodeConcentration, Value: 221.3200073, Anomaly: True
# T: 492, Timestamp: 2021-10-28 08:12:00+00:00, Variable: OptodeConcentration, Value: 220.2599945, Anomaly: True
# T: 501, Timestamp: 2021-10-28 08:21:00+00:00, Variable: FlowFlow, Value: 12.30000019, Anomaly: True
# T: 603, Timestamp: 2021-10-28 10:03:00+00:00, Variable: FlowFlow, Value: 2.200000048, Anomaly: True
# T: 603, Timestamp: 2021-10-28 10:03:00+00:00, Variable: OptodeConcentration, Value: 219.8800049, Anomaly: True
# T: 604, Timestamp: 2021-10-28 10:04:00+00:00, Variable: FlowFlow, Value: 1.5, Anomaly: True
# T: 604, Timestamp: 2021-10-28 10:04:00+00:00, Variable: FlowTemperature, Value: 31.5, Anomaly: True
# T: 604, Timestamp: 2021-10-28 10:04:00+00:00, Variable: OptodeConcentration, Value: 219.3399963, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: C3Temperature, Value: 30.43000031, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: C3Turbidity, Value: 7.0, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: FlowFlow, Value: 8.100000381, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: FlowTemperature, Value: 31.39999962, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: OptodeConcentration, Value: 215.5099945, Anomaly: True
# T: 605, Timestamp: 2021-10-28 10:05:00+00:00, Variable: OptodeSaturation, Value: 92.26999664, Anomaly: True
# T: 606, Timestamp: 2021-10-28 10:06:00+00:00, Variable: C3Temperature, Value: 30.0, Anomaly: True
# T: 606, Timestamp: 2021-10-28 10:06:00+00:00, Variable: C3Turbidity, Value: 1.33, Anomaly: True
# T: 606, Timestamp: 2021-10-28 10:06:00+00:00, Variable: FlowTemperature, Value: 31.60000038, Anomaly: True
# T: 606, Timestamp: 2021-10-28 10:06:00+00:00, Variable: OptodeConcentration, Value: 236.6699982, Anomaly: True
# T: 606, Timestamp: 2021-10-28 10:06:00+00:00, Variable: OptodeSaturation, Value: 100.5199966, Anomaly: True
# T: 607, Timestamp: 2021-10-28 10:07:00+00:00, Variable: C3Temperature, Value: 30.04000092, Anomaly: True
# T: 607, Timestamp: 2021-10-28 10:07:00+00:00, Variable: C3Turbidity, Value: 1.33, Anomaly: True
# T: 607, Timestamp: 2021-10-28 10:07:00+00:00, Variable: OptodeConcentration, Value: 239.7100067, Anomaly: True
# T: 607, Timestamp: 2021-10-28 10:07:00+00:00, Variable: OptodeSaturation, Value: 101.8600006, Anomaly: True
# T: 608, Timestamp: 2021-10-28 10:08:00+00:00, Variable: C3Turbidity, Value: 1.29, Anomaly: True
# T: 608, Timestamp: 2021-10-28 10:08:00+00:00, Variable: OptodeConcentration, Value: 232.7100067, Anomaly: True
# T: 608, Timestamp: 2021-10-28 10:08:00+00:00, Variable: OptodeSaturation, Value: 98.88999939, Anomaly: True
# T: 609, Timestamp: 2021-10-28 10:09:00+00:00, Variable: OptodeConcentration, Value: 229.9900055, Anomaly: True
# T: 609, Timestamp: 2021-10-28 10:09:00+00:00, Variable: OptodeSaturation, Value: 97.73999786, Anomaly: True
# T: 610, Timestamp: 2021-10-28 10:10:00+00:00, Variable: OptodeConcentration, Value: 229.4799957, Anomaly: True
# T: 610, Timestamp: 2021-10-28 10:10:00+00:00, Variable: OptodeSaturation, Value: 97.51999664, Anomaly: True
# T: 611, Timestamp: 2021-10-28 10:11:00+00:00, Variable: OptodeConcentration, Value: 229.2200012, Anomaly: True
# T: 695, Timestamp: 2021-10-28 11:35:00+00:00, Variable: FlowTemperature, Value: 31.39999962, Anomaly: True
# T: 696, Timestamp: 2021-10-28 11:36:00+00:00, Variable: C3Temperature, Value: 29.77000046, Anomaly: True
# T: 696, Timestamp: 2021-10-28 11:36:00+00:00, Variable: FlowTemperature, Value: 31.39999962, Anomaly: True
# T: 696, Timestamp: 2021-10-28 11:36:00+00:00, Variable: SEB45Conductivity, Value: 5.755000114, Anomaly: True
# T: 697, Timestamp: 2021-10-28 11:37:00+00:00, Variable: C3Temperature, Value: 29.76000023, Anomaly: True
# T: 735, Timestamp: 2021-10-28 12:15:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 736, Timestamp: 2021-10-28 12:16:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 736, Timestamp: 2021-10-28 12:16:00+00:00, Variable: FlowTemperature, Value: 32.20000076, Anomaly: True
# T: 736, Timestamp: 2021-10-28 12:16:00+00:00, Variable: OptodeConcentration, Value: 211.8300018, Anomaly: True
# T: 736, Timestamp: 2021-10-28 12:16:00+00:00, Variable: SEB45Conductivity, Value: 3.38499999, Anomaly: True
# T: 736, Timestamp: 2021-10-28 12:16:00+00:00, Variable: SEB45Salinity, Value: 19.154, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: FlowTemperature, Value: 33.20000076, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: OptodeConcentration, Value: 208.5599976, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: OptodeSaturation, Value: 89.23999786, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: SEB45Conductivity, Value: 3.128999949, Anomaly: True
# T: 737, Timestamp: 2021-10-28 12:17:00+00:00, Variable: SEB45Salinity, Value: 17.537, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: C3Temperature, Value: 30.03000069, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: FlowTemperature, Value: 33.70000076, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: OptodeConcentration, Value: 210.2100067, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: OptodeTemperature, Value: 30.79000092, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: SEB45Conductivity, Value: 0.2409999967, Anomaly: True
# T: 738, Timestamp: 2021-10-28 12:18:00+00:00, Variable: SEB45Salinity, Value: 1.109, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: C3Temperature, Value: 30.11000061, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: C3Turbidity, Value: 368.61, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: FlowTemperature, Value: 34.09999847, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: OptodeTemperature, Value: 31.15999985, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: SEB45Conductivity, Value: 0.2099999934, Anomaly: True
# T: 739, Timestamp: 2021-10-28 12:19:00+00:00, Variable: SEB45Salinity, Value: 0.961, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: C3Temperature, Value: 30.22999954, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: C3Turbidity, Value: 445.6, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: FlowTemperature, Value: 34.09999847, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: OptodeTemperature, Value: 31.40999985, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: SEB45Conductivity, Value: 0.199000001, Anomaly: True
# T: 740, Timestamp: 2021-10-28 12:20:00+00:00, Variable: SEB45Salinity, Value: 0.905, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: C3Temperature, Value: 30.37999916, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: C3Turbidity, Value: 552.33, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: FlowTemperature, Value: 34.29999924, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: OptodeTemperature, Value: 31.72999954, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: SEB45Conductivity, Value: 0.1879999936, Anomaly: True
# T: 741, Timestamp: 2021-10-28 12:21:00+00:00, Variable: SEB45Salinity, Value: 0.851, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: C3Temperature, Value: 30.53000069, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: FlowTemperature, Value: 34.79999924, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: OptodeTemperature, Value: 31.96999931, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: SEB45Conductivity, Value: 0.1800000072, Anomaly: True
# T: 742, Timestamp: 2021-10-28 12:22:00+00:00, Variable: SEB45Salinity, Value: 0.814, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: C3Temperature, Value: 30.68000031, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: FlowTemperature, Value: 34.90000153, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: OptodeTemperature, Value: 32.18999863, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: SEB45Conductivity, Value: 0.175999999, Anomaly: True
# T: 743, Timestamp: 2021-10-28 12:23:00+00:00, Variable: SEB45Salinity, Value: 0.792, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: C3Temperature, Value: 30.81999969, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: FlowTemperature, Value: 34.90000153, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: OptodeTemperature, Value: 32.40000153, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: SEB45Conductivity, Value: 0.1710000038, Anomaly: True
# T: 744, Timestamp: 2021-10-28 12:24:00+00:00, Variable: SEB45Salinity, Value: 0.766, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: C3Temperature, Value: 31.0, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: FlowFlow, Value: 0.0, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: FlowTemperature, Value: 35.29999924, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: OptodeTemperature, Value: 32.59000015, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: SEB45Conductivity, Value: 0.1669999957, Anomaly: True
# T: 745, Timestamp: 2021-10-28 12:25:00+00:00, Variable: SEB45Salinity, Value: 0.745, Anomaly: True
# T: 746, Timestamp: 2021-10-28 12:26:00+00:00, Variable: C3Temperature, Value: 31.18000031, Anomaly: True
# T: 746, Timestamp: 2021-10-28 12:26:00+00:00, Variable: FlowTemperature, Value: 35.59999847, Anomaly: True
# T: 746, Timestamp: 2021-10-28 12:26:00+00:00, Variable: OptodeTemperature, Value: 32.75999832, Anomaly: True
# T: 746, Timestamp: 2021-10-28 12:26:00+00:00, Variable: SEB45Conductivity, Value: 0.1640000045, Anomaly: True
# T: 746, Timestamp: 2021-10-28 12:26:00+00:00, Variable: SEB45Salinity, Value: 0.731, Anomaly: True
# T: 747, Timestamp: 2021-10-28 12:27:00+00:00, Variable: C3Temperature, Value: 31.32999992, Anomaly: True
# T: 747, Timestamp: 2021-10-28 12:27:00+00:00, Variable: FlowTemperature, Value: 35.20000076, Anomaly: True
# T: 747, Timestamp: 2021-10-28 12:27:00+00:00, Variable: OptodeTemperature, Value: 32.93000031, Anomaly: True
# T: 747, Timestamp: 2021-10-28 12:27:00+00:00, Variable: SEB45Conductivity, Value: 0.1609999985, Anomaly: True
# T: 747, Timestamp: 2021-10-28 12:27:00+00:00, Variable: SEB45Salinity, Value: 0.713, Anomaly: True
# T: 748, Timestamp: 2021-10-28 12:28:00+00:00, Variable: C3Temperature, Value: 31.47999954, Anomaly: True
# T: 748, Timestamp: 2021-10-28 12:28:00+00:00, Variable: FlowTemperature, Value: 35.70000076, Anomaly: True
# T: 748, Timestamp: 2021-10-28 12:28:00+00:00, Variable: OptodeTemperature, Value: 33.09000015, Anomaly: True
# T: 748, Timestamp: 2021-10-28 12:28:00+00:00, Variable: SEB45Conductivity, Value: 0.1560000032, Anomaly: True
# T: 748, Timestamp: 2021-10-28 12:28:00+00:00, Variable: SEB45Salinity, Value: 0.69, Anomaly: True
# T: 749, Timestamp: 2021-10-28 12:29:00+00:00, Variable: C3Temperature, Value: 31.62000084, Anomaly: True
# T: 749, Timestamp: 2021-10-28 12:29:00+00:00, Variable: FlowTemperature, Value: 35.59999847, Anomaly: True
# T: 749, Timestamp: 2021-10-28 12:29:00+00:00, Variable: OptodeTemperature, Value: 33.24000168, Anomaly: True
# T: 749, Timestamp: 2021-10-28 12:29:00+00:00, Variable: SEB45Conductivity, Value: 0.1539999992, Anomaly: True
# T: 749, Timestamp: 2021-10-28 12:29:00+00:00, Variable: SEB45Salinity, Value: 0.679, Anomaly: True
# T: 750, Timestamp: 2021-10-28 12:30:00+00:00, Variable: C3Temperature, Value: 31.75, Anomaly: True
# T: 750, Timestamp: 2021-10-28 12:30:00+00:00, Variable: FlowTemperature, Value: 36.09999847, Anomaly: True
# T: 750, Timestamp: 2021-10-28 12:30:00+00:00, Variable: OptodeTemperature, Value: 33.36000061, Anomaly: True
# T: 750, Timestamp: 2021-10-28 12:30:00+00:00, Variable: SEB45Conductivity, Value: 0.150000006, Anomaly: True
# T: 750, Timestamp: 2021-10-28 12:30:00+00:00, Variable: SEB45Salinity, Value: 0.659, Anomaly: True
# T: 751, Timestamp: 2021-10-28 12:31:00+00:00, Variable: C3Temperature, Value: 31.92000008, Anomaly: True
# T: 751, Timestamp: 2021-10-28 12:31:00+00:00, Variable: FlowTemperature, Value: 36.40000153, Anomaly: True
# T: 751, Timestamp: 2021-10-28 12:31:00+00:00, Variable: OptodeTemperature, Value: 33.52000046, Anomaly: True
# T: 751, Timestamp: 2021-10-28 12:31:00+00:00, Variable: SEB45Salinity, Value: 0.646, Anomaly: True
# T: 752, Timestamp: 2021-10-28 12:32:00+00:00, Variable: C3Temperature, Value: 32.06999969, Anomaly: True
# T: 752, Timestamp: 2021-10-28 12:32:00+00:00, Variable: FlowTemperature, Value: 36.70000076, Anomaly: True
# T: 752, Timestamp: 2021-10-28 12:32:00+00:00, Variable: OptodeTemperature, Value: 33.54000092, Anomaly: True
# T: 753, Timestamp: 2021-10-28 12:33:00+00:00, Variable: C3Temperature, Value: 32.22999954, Anomaly: True
# T: 753, Timestamp: 2021-10-28 12:33:00+00:00, Variable: FlowTemperature, Value: 36.70000076, Anomaly: True
# T: 753, Timestamp: 2021-10-28 12:33:00+00:00, Variable: OptodeTemperature, Value: 33.52000046, Anomaly: True
# T: 754, Timestamp: 2021-10-28 12:34:00+00:00, Variable: C3Temperature, Value: 32.38000107, Anomaly: True
# T: 754, Timestamp: 2021-10-28 12:34:00+00:00, Variable: FlowTemperature, Value: 36.59999847, Anomaly: True
# T: 754, Timestamp: 2021-10-28 12:34:00+00:00, Variable: OptodeTemperature, Value: 33.43000031, Anomaly: True
# T: 755, Timestamp: 2021-10-28 12:35:00+00:00, Variable: C3Temperature, Value: 32.52999878, Anomaly: True
# T: 755, Timestamp: 2021-10-28 12:35:00+00:00, Variable: FlowTemperature, Value: 36.90000153, Anomaly: True
# T: 755, Timestamp: 2021-10-28 12:35:00+00:00, Variable: OptodeTemperature, Value: 34.22999954, Anomaly: True
# T: 756, Timestamp: 2021-10-28 12:36:00+00:00, Variable: C3Temperature, Value: 32.63999939, Anomaly: True
# T: 756, Timestamp: 2021-10-28 12:36:00+00:00, Variable: FlowTemperature, Value: 37.20000076, Anomaly: True
# T: 756, Timestamp: 2021-10-28 12:36:00+00:00, Variable: OptodeTemperature, Value: 33.97999954, Anomaly: True
# T: 757, Timestamp: 2021-10-28 12:37:00+00:00, Variable: C3Temperature, Value: 32.75999832, Anomaly: True
# T: 757, Timestamp: 2021-10-28 12:37:00+00:00, Variable: FlowTemperature, Value: 37.40000153, Anomaly: True
# T: 757, Timestamp: 2021-10-28 12:37:00+00:00, Variable: OptodeTemperature, Value: 33.93000031, Anomaly: True
# T: 758, Timestamp: 2021-10-28 12:38:00+00:00, Variable: C3Temperature, Value: 32.88999939, Anomaly: True
# T: 758, Timestamp: 2021-10-28 12:38:00+00:00, Variable: FlowTemperature, Value: 37.29999924, Anomaly: True
# T: 758, Timestamp: 2021-10-28 12:38:00+00:00, Variable: OptodeTemperature, Value: 33.88000107, Anomaly: True
# T: 759, Timestamp: 2021-10-28 12:39:00+00:00, Variable: C3Temperature, Value: 33.09999847, Anomaly: True
# T: 759, Timestamp: 2021-10-28 12:39:00+00:00, Variable: FlowTemperature, Value: 33.70000076, Anomaly: True
# T: 759, Timestamp: 2021-10-28 12:39:00+00:00, Variable: OptodeTemperature, Value: 33.54999924, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: C3Temperature, Value: 30.73999977, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: C3Turbidity, Value: 1.16, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: FlowTemperature, Value: 32.0, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: OptodeConcentration, Value: 220.0800018, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: OptodeSaturation, Value: 94.94999695, Anomaly: True
# T: 760, Timestamp: 2021-10-28 12:40:00+00:00, Variable: OptodeTemperature, Value: 31.03000069, Anomaly: True
# T: 761, Timestamp: 2021-10-28 12:41:00+00:00, Variable: C3Temperature, Value: 29.90999985, Anomaly: True
# T: 761, Timestamp: 2021-10-28 12:41:00+00:00, Variable: C3Turbidity, Value: 1.15, Anomaly: True
# T: 761, Timestamp: 2021-10-28 12:41:00+00:00, Variable: OptodeConcentration, Value: 223.1799927, Anomaly: True
# T: 761, Timestamp: 2021-10-28 12:41:00+00:00, Variable: OptodeTemperature, Value: 30.17000008, Anomaly: True
# T: 762, Timestamp: 2021-10-28 12:42:00+00:00, Variable: C3Temperature, Value: 29.85000038, Anomaly: True
# T: 762, Timestamp: 2021-10-28 12:42:00+00:00, Variable: C3Turbidity, Value: 1.12, Anomaly: True
# T: 762, Timestamp: 2021-10-28 12:42:00+00:00, Variable: OptodeConcentration, Value: 224.1499939, Anomaly: True
# T: 763, Timestamp: 2021-10-28 12:43:00+00:00, Variable: C3Turbidity, Value: 1.26, Anomaly: True
# T: 763, Timestamp: 2021-10-28 12:43:00+00:00, Variable: OptodeConcentration, Value: 224.4499969, Anomaly: True
# T: 764, Timestamp: 2021-10-28 12:44:00+00:00, Variable: C3Turbidity, Value: 1.29, Anomaly: True
# T: 765, Timestamp: 2021-10-28 12:45:00+00:00, Variable: C3Turbidity, Value: 1.29, Anomaly: True
# T: 766, Timestamp: 2021-10-28 12:46:00+00:00, Variable: C3Turbidity, Value: 1.29, Anomaly: True
# T: 3137, Timestamp: 2021-10-30 04:18:00+00:00, Variable: OptodeConcentration, Value: 215.4299927, Anomaly: True
# T: 3487, Timestamp: 2021-10-30 10:09:00+00:00, Variable: OptodeConcentration, Value: 243.3899994, Anomaly: True
# T: 3487, Timestamp: 2021-10-30 10:09:00+00:00, Variable: OptodeSaturation, Value: 103.8700027, Anomaly: True
# T: 3488, Timestamp: 2021-10-30 10:10:00+00:00, Variable: OptodeConcentration, Value: 243.2100067, Anomaly: True
# T: 3488, Timestamp: 2021-10-30 10:10:00+00:00, Variable: OptodeSaturation, Value: 103.7799988, Anomaly: True
# T: 3489, Timestamp: 2021-10-30 10:11:00+00:00, Variable: OptodeConcentration, Value: 245.7299957, Anomaly: True
# T: 3490, Timestamp: 2021-10-30 10:12:00+00:00, Variable: OptodeConcentration, Value: 234.1300049, Anomaly: True
# T: 3491, Timestamp: 2021-10-30 10:13:00+00:00, Variable: OptodeConcentration, Value: 231.9100037, Anomaly: True
# T: 3492, Timestamp: 2021-10-30 10:14:00+00:00, Variable: OptodeConcentration, Value: 231.4499969, Anomaly: True
# T: 4210, Timestamp: 2021-10-30 22:14:00+00:00, Variable: OptodeConcentration, Value: 247.9799957, Anomaly: True
# T: 4211, Timestamp: 2021-10-30 22:15:00+00:00, Variable: OptodeConcentration, Value: 235.7899933, Anomaly: True
# T: 4212, Timestamp: 2021-10-30 22:16:00+00:00, Variable: OptodeConcentration, Value: 232.7599945, Anomaly: True
# T: 4213, Timestamp: 2021-10-30 22:17:00+00:00, Variable: OptodeConcentration, Value: 232.1300049, Anomaly: True
# timestamp 2021-10-30 23:59:00+00:00
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# No events found in range.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 278
#     275 else:
#     276 	print("No events found in range.")
# --> 278 time.sleep(poll_interval)
#
# KeyboardInterrupt:
